# %%
import numpy as np
import pandas as pd 
import sklearn
import seaborn as sb
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv("Project9.csv")
df.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
df.shape
# Out:
# (58, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %%
df.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %% [markdown]
# Data Cleaning

# %%
#Replacing the question mark with NaN
df = df.replace('?',np.nan)
df
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %%
#Checking Presence of NaN Values
df.isnull().values.any()
# Out:
# True

# %%
#As Null Values are Identified, Let's Check the Count Present 
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
for col in ['Hospitalization_Rate','Testing_Rate','Mortality_Rate','People_Hospitalized','People_Tested','Incident_Rate','Recovered','Long_','Lat']:
    df[col].fillna(df[col].mean(),inplace=True)

df
# Out:
#               Province_State Country_Region          Last_Update        Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.318200
# 1                     Alaska             US  2020-05-21 02:32:54  61.370700
# 2             American Samoa             US  2020-05-21 02:32:54 -14.271000
# 3                    Arizona             US  2020-05-21 02:32:54  33.729800
# 4                   Arkansas             US  2020-05-21 02:32:54  34.969700
# 5                 California             US  2020-05-21 02:32:54  36.116200
# 6                   Colorado             US  2020-05-21 02:32:54  39.059800
# 7                Connecticut             US  2020-05-21 02:32:54  41.597800
# 8                   Delaware             US  2020-05-21 02:32:54  39.318500
# 9           Diamond Princess             US  2020-05-21 02:32:54  36.840089
# 10      District of Columbia             US  2020-05-21 02:32:54  38.897400
# ...

# %%
#Checking Once Again Presence of NaN Values
df.isnull().values.any()
# Out:
# False

# %%
sb.heatmap(df.isnull())

# %% [markdown]
# No Null Values Identitfied

# %%
df.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  58.000000   58.000000      58.000000     58.000000     58.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.694329   48.873770   52562.031122   4084.750891   9901.304545
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.872800  -99.697700    2596.000000     74.000000   1281.750000
# 50%    38.978600  -86.797300   10148.500000    385.000000   4987.000000
# 75%    42.214075  -77.072550   29395.500000   1394.250000   7007.428571
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      58.000000   5.800000e+01
# mean    20070.724138   3288.086207     396.230806   2.258534e+05
# std     41294.705318  17408.350591     395.554852   2.934948e+05
# ...

# %% [markdown]
# Correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                            Lat     Long_  Confirmed    Deaths  Recovered  \
# Lat                   1.000000 -0.278274   0.120391  0.119685   0.030196
# Long_                -0.278274  1.000000   0.009951  0.028690  -0.041588
# Confirmed             0.120391  0.009951   1.000000  0.982191   0.822547
# Deaths                0.119685  0.028690   0.982191  1.000000   0.830223
# Recovered             0.030196 -0.041588   0.822547  0.830223   1.000000
# Active                0.119635  0.011604   0.985218  0.954378   0.725085
# FIPS                 -0.000404  0.000396  -0.096696 -0.075053  -0.000012
# Incident_Rate         0.245693  0.041318   0.708436  0.710105   0.542795
# People_Tested         0.084769 -0.077781   0.824136  0.739634   0.711255
# People_Hospitalized   0.026456  0.079677   0.869267  0.908279   0.761829
# Mortality_Rate       -0.134906  0.297192   0.382537  0.427127   0.322160
# UID                   0.772768 -0.525997   0.153972  0.120043   0.130314
# ...

# %%
corr=df.corr()
plt.figure(figsize=(15,7))
sb.heatmap(corr,annot=True,linewidths=0.5,linecolor="black",fmt=".2f")
plt.show()

# %% [markdown]
# Uni Variant

# %%
plt.subplots(figsize=(32,12))
sb.countplot(x='Deaths',data=df)
plt.title("Deaths")
plt.xlabel('Deaths')
plt.ylabel('Count')
plt.show()

# %%
plt.subplots(figsize=(12,8))
sb.countplot(x='ISO3',data=df)
plt.title("ISO3")
plt.xlabel('ISO3')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# USA has more count of Covid - 19 Cases

# %%
plt.bar(df.index,df['Testing_Rate'])
plt.show()

# %% [markdown]
# Test Rate is High between 40 - 50 Range

# %%
plt.bar(df.index,df['Mortality_Rate'])
plt.show()

# %%
plt.bar(df.index,df['Hospitalization_Rate'])
plt.show()

# %% [markdown]
# Hospitalization Rate is highest in Range Between range 0 - 10

# %% [markdown]
# Bi Variant Ananlysis

# %%
plt.scatter(df["People_Tested"],df['Confirmed'])
plt.title("Bi Variant Analysis With People Tested & Confirmed ")
plt.ylabel('People_Tested')
plt.xlabel('Confirmed')
plt.show()

# %%
plt.scatter(df["Recovered"],df['Confirmed'])
plt.title("Bi Variant Analysis With People Tested & Confirmed ")
plt.ylabel('Recovered')
plt.xlabel('Confirmed')
plt.show()

# %%
fig = plt.figure(figsize = (20,25))
ax = fig.gca()
df.hist(ax = ax)

import warnings
warnings.filterwarnings('ignore')
# Out:
# <ipython-input-22-56f0836b61fb>:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df.hist(ax = ax)

# %%
sb.pairplot(df)

# %% [markdown]
# Checking Outlier

# %%
df.columns.values
# Out:
# array(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS',
#        'Incident_Rate', 'People_Tested', 'People_Hospitalized',
#        'Mortality_Rate', 'UID', 'ISO3', 'Testing_Rate',
#        'Hospitalization_Rate'], dtype=object)

# %%
collist=df.select_dtypes(include=['float']).columns
ncol=10
nrows=9
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sb.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# Checking Skewness

# %%
round(df.skew(),2)
# Out:
# Lat                    -2.25
# Long_                   3.57
# Confirmed               4.71
# Deaths                  5.49
# Recovered               3.65
# Active                  4.18
# FIPS                    5.27
# Incident_Rate           1.99
# People_Tested           2.83
# People_Hospitalized     6.87
# Mortality_Rate          0.50
# UID                    -3.03
# Testing_Rate            1.31
# Hospitalization_Rate    0.87
# dtype: float64

# %% [markdown]
# Except Mortaility Rate All Others Are Having High Skewness Above .55

# %%
#treating the skewness with Square and Cube Root Method

df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df[col].skew()>0.55:
            df[col]=np.sqrt(df[col])
        if df[col].skew()<0.55:
            df[col]=np.cbrt(df[col])

# %%
#Encoding Object Type Columns
from sklearn.preprocessing import LabelEncoder

chol=['Province_State','Country_Region','Last_Update','ISO3']

for val in chol:
    le=LabelEncoder()
    df[val]=le.fit_transform(df[val].astype(str))

# %% [markdown]
# Death is Dependent Varible is considered as y and Rest factores is considered as x

# %%
y=df["Deaths"]
y
# Out:
# 0      22.847319
# 1       3.162278
# 2       0.000000
# 3      27.331301
# 4      10.344080
# 5      59.135438
# 6      36.041643
# 7      59.405387
# 8      17.606817
# 9       0.000000
# 10     20.174241
# 11     45.782093
# 12     41.194660
# 13      1.732051
# 14      2.236068
# 15      4.123106
# 16      8.774964
# 17     67.268120
# 18     43.174066
# 19     19.824228
# 20     14.212670
# 21     19.390719
# 22     51.068581
# 23      8.544004
# 24     46.076024
# 25     77.884530
# 26     71.133677
# 27     28.035692
# 28     23.874673
# 29     25.298221
# 30      4.000000
# 31     11.747340
# 32     19.416488
# 33     13.784049
# 34    103.677384
# 35     16.822604
# 36    169.221748
# 37     26.944387
# 38      7.000000
# 39      1.414214
# 40     42.201896
# 41     17.291616
# 42     12.000000
# 43     69.065187
# 44     11.180340
# 45     23.194827
# 46     20.174241
# 47      6.782330
# 48     17.464249
# 49     37.762415
# 50      9.486833
# 51      7.348469
# ...

# %%
df_new=df.drop(['Deaths'],axis=1)
df_new=df.drop(['Long_'],axis=1)
x=df_new

# %%
print (x.shape,'\t\t',y.shape)
# Out:
# (58, 17) 		 (58,)

# %%
#Scaling the input Values

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_t=sc.fit_transform(x)
x_t
# Out:
# array([[-1.70244092e+00,  0.00000000e+00,  0.00000000e+00,
#         -5.95434673e-02, -9.29654060e-02, -1.65723943e-01,
#          2.90041995e-01,  1.11201842e-01, -2.68659634e-01,
#         -1.85359224e-01,  5.61394408e-03, -5.39348860e-01,
#         -2.68817466e-03,  3.07090457e-01,  2.17198770e-01,
#         -4.65845082e-02, -7.40821139e-01],
#        [-1.64270615e+00,  0.00000000e+00,  0.00000000e+00,
#          8.90926736e-01, -9.77608586e-01, -8.42674726e-01,
#         -1.15999637e+00, -9.51328627e-01, -2.61144831e-01,
#         -1.21400590e+00, -8.46327095e-01,  2.92274394e-01,
#         -7.02802998e-01,  3.07090471e-01,  2.17198770e-01,
#          6.49442118e-01,  1.07868088e-01],
#        [-1.58297138e+00,  0.00000000e+00,  0.00000000e+00,
#         -7.08434230e+00, -1.16562490e+00, -9.51422596e-01,
#          2.90041995e-01, -1.01410982e+00, -1.46272019e-01,
#         -2.06859362e+00, -1.57143551e+00,  2.92274394e-01,
# ...

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-2.01911732e+00,  0.00000000e+00,  0.00000000e+00,
#         -5.91279272e-01,  1.79872291e-01,  1.90275543e-01,
#          4.62078524e-01,  4.53697798e-01, -3.43143300e+00,
#         -8.30725364e-02,  1.68513144e-01, -4.70806095e-01,
#         -1.56980297e-01,  3.07002550e-01,  1.16481265e-01,
#         -2.00517751e-01, -7.53745242e-01],
#        [-1.88815112e+00,  0.00000000e+00,  0.00000000e+00,
#          3.05243534e+00, -1.26117704e+00, -1.29851135e+00,
#         -1.41482677e+00, -1.46138747e+00, -2.66999500e+00,
#         -1.32309958e+00, -8.24154607e-01,  4.85727177e-01,
#         -8.98784869e-01,  3.07002590e-01,  1.16481265e-01,
#          6.81824213e-01,  8.47215337e-02],
#        [-1.77514253e+00,  0.00000000e+00,  0.00000000e+00,
#         -3.28539884e+00, -2.39816918e+00, -2.19307313e+00,
#          4.62078524e-01, -2.14604409e+00,  6.57657523e-01,
#         -3.08002322e+00, -2.49698635e+00,  4.85727177e-01,
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score

# %%
max_scr=0
for i in range(0,6000):
    x_train,x_test,y_train,y_test=train_test_split(x_t,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round (r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print("At Random State",i,". The Model Is Performing Very Well")
        print("At Random State:-",i)
        print("Training r2_score is",r2_score(y_train,pred_train)*100)
        print("Testing r2_score is",r2_score(y_test,pred_test)*100)
# Out:
# At Random State 0 . The Model Is Performing Very Well
# At Random State:- 0
# Training r2_score is 100.0
# Testing r2_score is 100.0
# At Random State 1 . The Model Is Performing Very Well
# At Random State:- 1
# Training r2_score is 100.0
# Testing r2_score is 100.0
# At Random State 2 . The Model Is Performing Very Well
# At Random State:- 2
# Training r2_score is 100.0
# Testing r2_score is 100.0
# At Random State 3 . The Model Is Performing Very Well
# At Random State:- 3
# Training r2_score is 100.0
# Testing r2_score is 100.0
# At Random State 4 . The Model Is Performing Very Well
# At Random State:- 4
# Training r2_score is 100.0
# Testing r2_score is 100.0
# At Random State 5 . The Model Is Performing Very Well
# At Random State:- 5
# Training r2_score is 100.0
# Testing r2_score is 100.0
# At Random State 6 . The Model Is Performing Very Well
# At Random State:- 6
# Training r2_score is 100.0
# Testing r2_score is 100.0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x_t,y,test_size=0.20,random_state=14) #Random state = 14

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Regularisation

# %% [markdown]
# Lasso

# %%
from sklearn.linear_model import Lasso
parameters ={'alpha':[.00001,.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print (clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
for j in range(2,10):
    lsscore = cross_val_score(ls,x_t,y,cv=j)
    lsc=lsscore.mean()
    print("At CV :-",j)
    print("Cross Validation Score is :-",lsc*100)
    print ("R2_score is :-",lss*100)
    print('\n')
# Out:
# At CV :- 2
# Cross Validation Score is :- 99.99854265691366
# R2_score is :- 99.99999602429914
#
#
# At CV :- 3
# Cross Validation Score is :- 99.99983103700872
# R2_score is :- 99.99999602429914
#
#
# At CV :- 4
# Cross Validation Score is :- 99.99980051822054
# R2_score is :- 99.99999602429914
#
#
# At CV :- 5
# Cross Validation Score is :- 99.99993328973822
# R2_score is :- 99.99999602429914
#
#
# At CV :- 6
# Cross Validation Score is :- 99.99996436904148
# R2_score is :- 99.99999602429914
#
#
# At CV :- 7
# Cross Validation Score is :- 99.99994341582281
# R2_score is :- 99.99999602429914
#
#
# At CV :- 8
# Cross Validation Score is :- 99.99990916832262
# R2_score is :- 99.99999602429914
#
#
# At CV :- 9
# Cross Validation Score is :- 99.99990884584028
# R2_score is :- 99.99999602429914

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print("Error:")
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_ls))
print("Mean Square Error:",mean_squared_error(y_test,pred_ls))
print("Root Mean Sqaured Error:", np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Error:
# Mean Absolute Error: 0.004413421701752481
# Mean Square Error: 2.8176997692174382e-05
# Root Mean Sqaured Error: 0.0053082009845308595

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_ls,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Deaths',fontsize=14)
plt.ylabel('Predicted Deaths',fontsize=14)
plt.title('Lasso Regression',fontsize=18)
plt.show()

# %% [markdown]
# All Date Points are inline and are lying on dataset

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge
parameters ={'alpha':[.0001,.001,.01,.1,1],'fit_intercept':[True,False],'normalize':[True,False],'random_state':[1,2,3,4,5,6,7,8,9]}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train,y_train)
print (clf.best_params_)
# Out:
# {'alpha': 0.0001, 'fit_intercept': True, 'normalize': False, 'random_state': 1}

# %%
ridge=Ridge(alpha=0.0001,random_state=1,fit_intercept=True,normalize= False)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_rd=rd.predict(x_test)

rdd=r2_score(y_test,pred_rd)
for j in range(2,10):
    rdscore = cross_val_score(rd,x_t,y,cv=j)
    rdc=rdscore.mean()
    print("At CV :-",j)
    print("Cross Validation Score is :-",rdc*100)
    print ("R2_score is :-",rdc*100)
    print('\n')
# Out:
# At CV :- 2
# Cross Validation Score is :- 97.3866830989109
# R2_score is :- 97.3866830989109
#
#
# At CV :- 3
# Cross Validation Score is :- 95.85496827865879
# R2_score is :- 95.85496827865879
#
#
# At CV :- 4
# Cross Validation Score is :- 96.92975040506781
# R2_score is :- 96.92975040506781
#
#
# At CV :- 5
# Cross Validation Score is :- 97.17560542302766
# R2_score is :- 97.17560542302766
#
#
# At CV :- 6
# Cross Validation Score is :- 97.74018131524676
# R2_score is :- 97.74018131524676
#
#
# At CV :- 7
# Cross Validation Score is :- 98.2357284547884
# R2_score is :- 98.2357284547884
#
#
# At CV :- 8
# Cross Validation Score is :- 97.45893698868579
# R2_score is :- 97.45893698868579
#
#
# At CV :- 9
# Cross Validation Score is :- 96.9503426497634
# R2_score is :- 96.9503426497634

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_rd,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Death',fontsize=14)
plt.ylabel('Predicted Death',fontsize=14)
plt.title('Rigde Regression',fontsize=18)
plt.show()

# %%
Few Data Points are lying outside the predicted point, Accuracy is only 97%

# %% [markdown]
# Ensemblier Technique

# %%
from sklearn.tree import DecisionTreeRegressor
parameters={'criterion':['mse','friedman_mse','mse'],'splitter':['best','random']}
dt=DecisionTreeRegressor()
clf=GridSearchCV(dt,parameters)
clf.fit(x_train,y_train)
print (clf.best_params_)
# Out:
# {'criterion': 'mse', 'splitter': 'random'}

# %%
dt=DecisionTreeRegressor(criterion='mse', splitter='best')
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
pred_decision=dt.predict(x_test)
dts=r2_score(y_test,pred_decision)
print("r2_score:",dts*100)
dtscore = cross_val_score(dt,x_t,y,cv=3)
dtc=dtscore.mean()
print('Cross Val Score:',dtc*100)
# Out:
# r2_score: 90.01494587661556
# Cross Val Score: 6.768519889846584

# %%
print("Error:")
print("Mean Absolute Error:",round(mean_absolute_error(y_test,pred_decision),2))
print("Mean Square Error:",round(mean_squared_error(y_test,pred_decision),2))
print("Root Mean Sqaured Error:",round(np.sqrt(mean_squared_error(y_test,pred_decision)),2))
# Out:
# Error:
# Mean Absolute Error: 5.24
# Mean Square Error: 70.77
# Root Mean Sqaured Error: 8.41

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_decision,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Deaths',fontsize=14)
plt.ylabel('Predicted Deaths',fontsize=14)
plt.title('Decision Tree Regression',fontsize=18)
plt.show()

# %% [markdown]
# Data Points are far away when copare with other models

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','friedman_mse','mse'],'n_estimators':[100,200,300]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print (clf.best_params_)
# Out:
# {'criterion': 'mse', 'n_estimators': 200}

# %%
rf=RandomForestRegressor(criterion='mse', n_estimators= 200)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_rd=rf.predict(x_test)
rfs=r2_score(y_test,pred_rd)
print("r2_score:",rfs*100)
rfscore = cross_val_score(rf,x_t,y,cv=3)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# r2_score: 90.80953074023604
# Cross Val Score: 81.29693565911401

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_rd,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Avg Price',fontsize=14)
plt.ylabel('Predicted Avg Price',fontsize=14)
plt.title('Random Forest Regressor',fontsize=18)
plt.show()

# %% [markdown]
# Datapoints are not inline with the predicted line

# %% [markdown]
# Gredient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
parameters={'loss':['ls','lad','huber','quantile'],'n_estimators':[50,100,200],'criterion':['friedman_mse','mse']}
gbr=GradientBoostingRegressor()
clf=GridSearchCV(gbr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'loss': 'lad', 'n_estimators': 200}

# %%
gbr=GradientBoostingRegressor(criterion='mse', loss='lad',n_estimators=200)
gbr.fit(x_train,y_train)
gbr.score(x_train,y_train)
pred_random=gbr.predict(x_test)
gbrs=r2_score(y_test,pred_random)
print("r2_score:",round(gbrs*100,2))
gbscore = cross_val_score(gbr,x_t,y,cv=3)
gbrc=gbscore.mean()
print('Cross Val Score:',round(gbrc*100,2))
# Out:
# r2_score: 88.99
# Cross Val Score: 84.74

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_random,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Deaths',fontsize=14)
plt.ylabel('Predicted Deaths',fontsize=14)
plt.title('GradientBoostingRegressor',fontsize=18)
plt.show()

# %% [markdown]
# Few Datapoints are far from dataline, Accuarcy is 84%

# %%
from sklearn.svm import SVR
parameters = {'kernel':['linear','poly','rbf','sigmoid']}
sv=SVR()
clf=GridSearchCV(sv,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'kernel': 'linear'}

# %%
sv=SVR(kernel='linear',gamma='auto')
sv.fit(x_train,y_train)
sv.score(x_train,y_train)
pred_vector=sv.predict(x_test)
svs=r2_score(y_test,pred_vector)
print("r2_score:",round(svs*100,2))
svscore = cross_val_score(sv,x_t,y,cv=3)
svc=svscore.mean()
print('Cross Val Score:',round(svc*100,2))
# Out:
# r2_score: 97.37
# Cross Val Score: 92.34

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_vector,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Death',fontsize=14)
plt.ylabel('Predicted Death',fontsize=14)
plt.title('Support Vector Regressior',fontsize=18)
plt.show()

# %%
import numpy as np
a=np.array(y_test)
a
# Out:
# array([ 11.74734012,   9.48683298,   0.        ,  36.04164258,
#          7.34846923,  11.18033989,  17.4642492 ,  16.82260384,
#         20.174241  , 103.67738423,   8.30662386,   3.31662479])

# %%
df_com=pd.DataFrame({"Original":a,"Predicted":pred_ls},index=range(len(a)))
df_com
# Out:
#       Original   Predicted
# 0    11.747340   11.759430
# 1     9.486833    9.490576
# 2     0.000000   -0.002569
# 3    36.041643   36.043777
# 4     7.348469    7.344388
# 5    11.180340   11.183482
# 6    17.464249   17.470947
# 7    16.822604   16.818757
# 8    20.174241   20.173004
# 9   103.677384  103.683858
# 10    8.306624    8.300598
# 11    3.316625    3.315705

# %%
import pickle
filename='AR_Project3.pkl'
pickle.dump(ls,open(filename,'wb'))
